# %% [markdown]
# #### PROJECT : RESORTS BOOKER
#
# #### AUTHOR : PRIYADHARSHINI R
#
# #### TECH STACKS:
#
# 1. Language: Python
# 2. Front End: Python(tkinter) Library
# 3. Back End: Oracle SQL

# %% [markdown]
# #### --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 1. INSTALLATION OF [cx_oracle] FOR BACK END CONNECTIVITY

# %%
# !pip install cx_oracle

# %%
# !pip install tkcalendar
# !pip install Pillow --user

# %% [markdown]
# #### 2. IMPORTING NECESSARY LIBRARY

# %%
import cx_Oracle
import tkinter as tk
from tkinter import *
from tkinter import ttk
import sys
import webbrowser
from datetime import date
import re
from PIL import ImageTk
from PIL import Image
from tkinter import messagebox
from tkinter.scrolledtext import ScrolledText
from tkcalendar import * 
import time
import datetime
from datetime import date

# %% [markdown]
# #### 3. ESTABLISHING CONNECTION

# %%
conn=cx_Oracle.connect('system/Rdph12345@@//localhost:1521/orcl')

# %%
print(conn.version)
# Out:
# 19.3.0.0.0

# %%
cursor = conn.cursor()

# %% [markdown]
# #### 4. CREATING TABLES

# %%
#cursor.execute("create table Register_Table(User_Name varchar2(30), E_Mail varchar2(35) primary key, Password varchar2(20), Confirm_Password varchar2(20))")
#cursor.execute("create table User_Booking_Details(G_ID varchar2(10) primary key, First_Name varchar2(30),Last_Name varchar2(30),Member_Count int,NO_OF_ROOMS int,Check_In varchar2(20),Check_Out varchar2(30),Days_Stay int, Room_Type varchar2(30),Room_Price float,Service_Tax float,Total_Amount float)");
#cursor.execute("create table User_Details_Table1(G_ID varchar2(10) primary key, First_Name varchar2(30), Last_Name varchar2(30), Area_Name varchar2(30), City varchar2(20), State varchar2(20), Zip_Code varchar2(10), Country varchar2(20), Phone_Number varchar2(12), Mail_ID varchar2(30))")
#cursor.execute("create table Available_Rooms1(ROOM_NO int primary key,ROOM_TYPE varchar2(30),TOTAL_LIMIT int, ROOM_PRICE float)")
#cursor.execute("create table OCCUPIED_ROOMS1(ROOM_NO int primary key,ROOM_TYPE varchar2(30),TOTAL_LIMIT int, ROOM_PRICE float)")

# %% [markdown]
# #### 5. SETTING TKINTER

# %%
root = Tk()
app_width = 1000
app_height=750
screen_width = root.winfo_screenwidth()
screen_height = root.winfo_screenheight()

x = (screen_width/2)-(app_width/2)
y = (screen_height/2)-(app_height/2)

root.geometry(f'{screen_width}x{screen_height}+{0}+{0}')

root.title(" RESORTS BOOKER: LOG IN PAGE")

bg = ImageTk.PhotoImage(file="cup1.jpeg")
bg_image = Label(root,image=bg).place(x=0,y=0,relwidth=1,relheight=1)

Frame_login = Frame(root,bg="white")
Frame_login.place(x=100,y=190,height=400,width=700)

#Declaring variable Globally
global Name
global User
global Password
global My_Label
global Next_btn
global Room_Num,clicked_number

Name=Entry(root)
User=Entry(root)
Password=Entry(root)
My_Label=Label(root)
Next_btn=Button(root)


def Submit1():
    global myLabel
    
    def Next():
       
        global bg_2,bg_img2
        top1 = Toplevel()
        top1.title("Palm Resorts")
        top1.geometry(f'{screen_width}x{screen_height}+{0}+{0}')

        bg_2 = ImageTk.PhotoImage(file="Palm1.jpg")
        bg_img2 = Label(top1,image=bg_2).place(x=0,y=0,relwidth=1,relheight=1)
        
        Frame_login2 = Frame(top1)
        Frame_login2.place(x=100,y=190,height=400,width=990)
        
        label3 = Label(top1,text="GREEN PALM RESORT GOA",font=('Cooper Black',25, 'bold'),bg="#104E8B",fg="orange")
        label3.place(x=0,y=0,relwidth=1)
        
        my_text = ScrolledText(Frame_login2,width=10, height= 10, font=('Californian FB',15, 'bold'),bg="#104E8B",fg="white")
        my_text.grid(row=1,column=0)
        
        text_file = open("sample.txt",'r')
        stuff = text_file.read()
        
        my_text.insert(END, stuff)
        my_text.pack(fill= BOTH, side= LEFT, expand= True)
        my_text.configure(state='disabled')
        
        text_file.close()
        
        def Gallery1():
            global photo,photo1,bg_3,bg_img3
            
            top2 = Toplevel()
            top2.title("Palm Resorts")
            top2.geometry(f'{screen_width}x{screen_height}+{0}+{0}')
            
            bg_3 = ImageTk.PhotoImage(file="bg.jpg")
            bg_img3 = Label(top2,image=bg_3).place(x=0,y=0,relwidth=1,relheight=1)
            
            photo = ImageTk.PhotoImage(file ="Goa1.jpg")
            photo1 = ImageTk.PhotoImage(file="Room1.jpg")
            
            def Sites_Gallery():
                global img1,img2,img3,img4,img5,x,top3,bg_5,bg_img5
                
                top3 = Toplevel()
                top3.title("Palm Resorts")
                top3.geometry(f'{screen_width}x{screen_height}+{0}+{0}')
                
                bg_5 = ImageTk.PhotoImage(file="bg.jpg")
                bg_img5 = Label(top3,image=bg_5).place(x=0,y=0,relwidth=1,relheight=1)
                
                Frame_login4 = Frame(top3)
                Frame_login4.place(x=150,y=130,height=600,width=1200)
                
                img1=ImageTk.PhotoImage(Image.open("Goa6.jpg"))
                img2=ImageTk.PhotoImage(Image.open("Goa2.jpg"))
                img3=ImageTk.PhotoImage(Image.open("Goa3.jpg"))
                img4=ImageTk.PhotoImage(Image.open("Goa4.jpg"))
                img5=ImageTk.PhotoImage(Image.open("Goa5.jpg"))

                l=Label(Frame_login4)
                l.pack()
                x = 1
                def move():
                    global x
                    if x == 6:
                        x = 1
                    if x == 1:
                        l.config(image=img1)
                    elif x == 2:
                        l.config(image=img2)
                    elif x == 3:
                        l.config(image=img3)
                    elif x == 4:
                        l.config(image=img4)
                    elif x == 5:
                        l.config(image=img5)
                    x = x+1
                    Frame_login4.after(2000, move)
                    
                move()
            
            def Rooms_Gallery():
                global img6,img7,img8,img9,img10,img11,y,top3,bg_6,bg_img6

                top4 = Toplevel()
                top4.title("Palm Resorts")
                top4.geometry(f'{screen_width}x{screen_height}+{0}+{0}')
                
                bg_6 = ImageTk.PhotoImage(file="bg.jpg")
                bg_img6 = Label(top4,image=bg_6).place(x=0,y=0,relwidth=1,relheight=1)

                Frame_login5 = Frame(top4)
                Frame_login5.place(x=150,y=130,height=600,width=1200)

                img6=ImageTk.PhotoImage(Image.open("Room1.jpg"))
                img7=ImageTk.PhotoImage(Image.open("Room2.jpg"))
                img8=ImageTk.PhotoImage(Image.open("Room3.jpg"))
                img9=ImageTk.PhotoImage(Image.open("Room4.jpg"))
                img10=ImageTk.PhotoImage(Image.open("Room5.jpeg"))
                img11=ImageTk.PhotoImage(Image.open("Room6.jpg"))

                l=Label(Frame_login5)
                l.pack()
                y = 1
                def move():
                    global y
                    if y == 7:
                        y = 1
                    if y == 1:
                        l.config(image=img6)
                    elif y == 2:
                        l.config(image=img7)
                    elif y == 3:
                        l.config(image=img8)
                    elif y == 4:
                        l.config(image=img9)
                    elif y == 5:
                        l.config(image=img10)
                    elif y == 6:
                        l.config(image=img11)
                    y = y+1
                    Frame_login5.after(2000, move)

                move()
                
            def Booking():
                global bg_7,bg_img7
                
                top5 = Toplevel()
                top5.title("Palm Resorts")
                top5.geometry(f'{screen_width}x{screen_height}+{0}+{0}')
                
                bg_7 = ImageTk.PhotoImage(file="palm3.jpg")
                bg_img7 = Label(top5,image=bg_7).place(x=0,y=0,relwidth=1,relheight=1)

                Frame_login5 = Frame(top5,bg="white")
                Frame_login5.place(x=150,y=60,height=720,width=1200)
                
                def Personal_Details():
                    global My_Label,cli2
                    
                    F_N = Book_Entry1.get()
                    L_N = Book_Entry2.get()
                    A_N = Book_Entry3.get()
                    City = Book_Entry4.get()
                    Zip_Code = Book_Entry10.get()
                    Phone = Book_Entry11.get()
                    Mail = Book_Entry12.get()
                    state = cli.get()
                    Country = cli1.get()
                    A_D = cal.get_date()
                    
                    def Checking():
                        global bg_8,bg_img8,Frame_login6
                        
                        top6 = Toplevel()
                        top6.title("Palm Resorts")
                        top6.geometry(f'{screen_width}x{screen_height}+{0}+{0}')

                        bg_8 = ImageTk.PhotoImage(file="palm3.jpg")
                        bg_img8 = Label(top6,image=bg_8).place(x=0,y=0,relwidth=1,relheight=1)

                        Frame_login6 = Frame(top6,bg="white")
                        Frame_login6.place(x=150,y=60,height=720,width=1200)
                        
                        Room_label1 = Label(Frame_login6,text="BOOKING PROCESS....",font=('Cooper Black',15, 'bold'),bg="white",fg="black")
                        Room_label1.place(x=0,y=0,relwidth=1)
                        
                        Book_label14 = Label(Frame_login6,text="MEMBERS COUNT",font=('times',15, 'bold'),bg="white",fg="black")
                        Book_label14.grid(row=1,column=0,padx=50,pady=50)
                        
                        Book_Entry13=Entry(Frame_login6,width=30,borderwidth=10, font=('times',15, 'bold'))
                        Book_Entry13.grid(row=1,column=1,padx=50,pady=50)
                
                        Book_label15 = Label(Frame_login6,text="SELECT ROOM TYPE",font=('times',15, 'bold'),bg="white",fg="black")
                        Book_label15.grid(row=2,column=0,padx=50,pady=50)
                        
                        def click():
                            
                            global clicked_number,Room_Num
                            
                            Room_type = type_room
                            table_select="""SELECT ROOM_NO FROM Available_Rooms1 WHERE ROOM_TYPE =:Room_type"""
                            cursor.execute(table_select,[Room_type])
                            room_no=cursor.fetchall()
                            print(room_no)
                            
                            a = [item for t in room_no for item in t]
                            
                            clicked_number=IntVar()
                            clicked_number.set(a[0])
                            
                            drop_number=OptionMenu(Frame_login6,clicked_number,*a)
                            drop_number.grid(row=4,column=1,padx=30,pady=30)
                            drop_number.config(width = 30,height= 2,font=('times', 15))
                            
                            Room_Num = clicked_number.get()
                        
                        def selected(event):
                                global type_room
                                type_room=cli2.get()
                                click()
                                
                        def Proceed():
                            
                            def Next():
                                atm = type11.get()
                                cvv = type13.get()
                                payment = payment1.get()
                                
                                def Sleep():
                                    
                                    type25=Label(Frame_login7,text="Thank You For Booking !",font=('Cooper Black',15, 'bold'),bg="white",fg="black")
                                    type25.grid(row=9,column=2)
                                    
                                if(len(atm)==0 and len(cvv)==0 and payment1.get()=="CHOICE IS YOURS!"):
                                    messagebox.showerror("showerror","Kindly Fill all the Details !!",parent=top7)

                                if re.fullmatch(r'^4[0-9]{12}(?:[0-9]{3})?$',atm):
                                        if re.fullmatch(r'^[0-9]{3,4}$',cvv):
                                                Room_Num = clicked_number.get()
                                                insertion_unc="""INSERT INTO OCCUPIED_ROOMS1 SELECT * FROM Available_Rooms1 WHERE ROOM_NO=:Room_Num"""
                                                cursor.execute(insertion_unc,[Room_Num])
                                                conn.commit()
                                                print("data_copied_successfully")
                                                deletion_unc="""DELETE FROM Available_Rooms1 WHERE ROOM_NO=:Room_Num"""
                                                cursor.execute(deletion_unc,[Room_Num])
                                                conn.commit()

                                                guest_id="""SELECT G_ID FROM USER_DETAILS_TABLE1"""
                                                room_no=Room_Num;
                                                cursor.execute(guest_id)
                                                ids=cursor.fetchall()
                                                last_length=len(ids)
                                                ids=ids[last_length-1]
                                                ids=list(ids)
                                                ids=ids[0]

                                                table_name="""SELECT FIRST_NAME FROM USER_DETAILS_TABLE1"""
                                                cursor.execute(table_name)
                                                names=cursor.fetchall()
                                                last_length_1=len(names)
                                                names=names[last_length_1-1]
                                                names=list(names)
                                                names=names[0]

                                                Last_name="""SELECT LAST_NAME FROM USER_DETAILS_TABLE1"""
                                                cursor.execute(Last_name)
                                                names1=cursor.fetchall()
                                                last_length_2=len(names1)
                                                names1=names1[last_length_2-1]
                                                names1=list(names1)
                                                names1=names1[0]

                                                member_count=Book_Entry13.get()
                                                no_of_rooms = count1

                                                if(type_room=="Normal"):
                                                    c_o_r=2000
                                                if(type_room=="Deluxe"):
                                                    c_o_r=4000
                                                if(type_room=="Suite"):
                                                    c_o_r=6000
                                                gst=GST
                                                total_1=Total_amount
                                                print(Total_amount)
                                                book_insert="""INSERT INTO User_Booking_Details VALUES(:G_ID,:First_Name,:Last_Name,:Member_Count,:NO_OF_ROOMS,:Check_In,:Check_Out,:Days_Stay,:Room_Type,:Room_Price,:Service_Tax,:Total_Amount)""" 
                                                cursor.execute(book_insert,[ids,names,names1,member_count,no_of_rooms,arrival.get_date(),departure.get_date(),Days_stay,type_room,c_o_r,gst,total_1])
                                                conn.commit()
                                                print("DETAILS INSERTED INTO BOOKING DETAILS!!!")
                                                
                                                type17=Label(Frame_login7,text="Loading.....",width = 20,font=('Cooper Black',15, 'bold'),bg="white",fg="black")
                                                type17.grid(row=9,column=2,columnspan=2)
                                                type17.after(3000,My_Label.destroy)
                                                Frame_login7.after(3000,Sleep)
                                               
                                        else:
                                             messagebox.showerror("showerror","Kindly Fill valid cvv !!",parent=top7)
                                else:
                                    messagebox.showerror("showerror","Kindly Fill valid Account number!!",parent=top7)
                            
                            global count1,bg_9,bg_img9
                            
                            top7 = Toplevel()
                            top7.title("Palm Resorts")
                            top7.geometry(f'{screen_width}x{screen_height}+{0}+{0}')

                            bg_9= ImageTk.PhotoImage(file="palm3.jpg")
                            bg_img9 = Label(top7,image=bg_9).place(x=0,y=0,relwidth=1,relheight=1)

                            Frame_login7 = Frame(top7,bg="white")
                            Frame_login7.place(x=150,y=60,height=720,width=1200)
                           
                            
                            date_1 = datetime.datetime.strptime(arrival.get_date(), "%m/%d/%y")
                            date_2 = datetime.datetime.strptime(departure.get_date(), "%m/%d/%y")
                            date = date_2 - date_1
                            str1 = str(date)
                            print(str1)
                            for i in range(len(str1)):
                                num = str1[0]
                            Days_stay = int(num)
                            Days_stay+=1
                            
                            limit = 2
                            
                            vals=[True]*8;
                            count = Book_Entry13.get()
                            Rooms = type_room
                            
                            if (len(count)==0):
                                top7.destroy()
                                messagebox.showerror("showerror","Enter Member Count",parent=top6)
                            else:
                                vals[0]=True                                
                            if (car_parks.get()=="CHOOSE!!"):
                                top7.destroy()
                                messagebox.showerror("showerror","choose Car Parking Access",parent=top6)
                            else:
                                vals[1]=True
                                
                            if (Days_stay < 0):
                                top7.destroy()
                                messagebox.showerror("showerror","Enter a Valid date",parent=top6)
                            else:
                                vals[2]=True
    
                                
                            if(vals[0]==True and vals[1]==True and vals[2]==True):
                                table_select_1="""SELECT ROOM_PRICE FROM Available_Rooms1 WHERE ROOM_TYPE = :type_room"""
                                cursor.execute(table_select_1,[type_room])
                                room_cost=cursor.fetchone()
                                cost_room=room_cost
                                print(cost_room)
                                print(Days_stay)
                                Total_cost=cost_room*Days_stay
                                Total_cost=sum(Total_cost)
                                GST=0.12*float(Total_cost)
                                Total_amount=Total_cost+GST
                                print(Total_amount)
                                members = int(count)
                                if (int(count)>limit):
                                    count1 = int(members/2)
                                    count2 = int(members%2)
                                    if(count2==1):
                                        count1+=1
                                    Total_amount = Total_amount*count1
                                else:
                                    print(Total_amount)
                                    count1=1
                            
                            bill1 = Label(Frame_login7,text="BOOKING PROCESS....",font=('Cooper Black',15, 'bold'),bg="white",fg="black")
                            bill1.grid(row=0,column=0,columnspan=3,padx=50,pady=30)
                                                                
                            type1=Label(Frame_login7,text="ROOM TYPE",width = 20,font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type1.grid(row=1,column=0,padx=50,pady=10)
                            
                            col1=Label(Frame_login7,text=""+str(type_room),width = 20,font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col1.grid(row=1,column=1,padx=50,pady=10)

                            type14=Label(Frame_login7,text="CHECK IN",width = 20,font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type14.grid(row=3,column=0,padx=50,pady=10)
                            
                            col2=Label(Frame_login7,width = 20,text=""+str(arrival.get_date()),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col2.grid(row=3,column=1,padx=50,pady=10)

                            type15=Label(Frame_login7,width = 20,text="CHECK OUT",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type15.grid(row=4,column=0,padx=50,pady=10)
                            
                            col3=Label(Frame_login7,width = 20,text=""+str(departure.get_date()),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col3.grid(row=4,column=1,padx=50,pady=10)

                            type2=Label(Frame_login7,width = 20,text="ROOM PRICE",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type2.grid(row=5,column=0,padx=50,pady=10)
                            
                            col4=Label(Frame_login7,width = 20,text=""+str(cost_room),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col4.grid(row=5,column=1,padx=50,pady=10)

                            type3=Label(Frame_login7,width = 20,text="NO OF MEMBERS",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type3.grid(row=6,column=0,padx=50,pady=10)
                            
                            col5=Label(Frame_login7,width = 20,text=""+str(members),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col5.grid(row=6,column=1,padx=50,pady=10)

                            type4=Label(Frame_login7,width = 20,text="DAYS SPEND",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type4.grid(row=7,column=0,padx=50,pady=10)
                            
                            col6=Label(Frame_login7,width = 20,text=""+str(Days_stay),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col6.grid(row=7,column=1,padx=50,pady=10)

                            type5=Label(Frame_login7,width = 20,text="NUMBER OF ROOMS",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type5.grid(row=8,column=0,padx=50,pady=10)
                            
                            col7=Label(Frame_login7,width = 20,text=""+str(count1),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col7.grid(row=8,column=1,padx=50,pady=10)

                            type6=Label(Frame_login7,width = 20,text="SERVICE TAX",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type6.grid(row=9,column=0,padx=50,pady=10)
                            
                            col8=Label(Frame_login7,width = 20,text=""+str(GST),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col8.grid(row=9,column=1,padx=50,pady=10)

                            type7=Label(Frame_login7,width = 20,text="TOTAL AMOUNT",font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            type7.grid(row=10,column=0,padx=50,pady=10)
                            
                            col9=Label(Frame_login7,width = 20,text=""+str(Total_amount),font=('times',15, 'bold'),bg="white",fg="black",borderwidth = 3,relief="ridge")
                            col9.grid(row=10,column=1,padx=50,pady=10)
                            
                            payment=['CREDIT CARD','DEBIT CARD']

                            payment1=StringVar()
                            payment1.set("CHOICE IS YOURS!")

                            type8=Label(Frame_login7,text="PAYMENT OPTIONS",font=('times',15, 'bold'),bg="white",fg="black")
                            type8.grid(row=1,column=2)
                            
                            type8_label=OptionMenu(Frame_login7,payment1,*payment)
                            type8_label.grid(row=2,column=2)
                            type8_label.config(width= 30,height= 2,font=('times', 15))
                                 
                            type10=Label(Frame_login7,text="ENTER YOUR ATM CARD NUMBER",font=('times',15, 'bold'),bg="white",fg="black")
                            type10.grid(row=4,column=2)
                                                                
                            type11=Entry(Frame_login7,width=35,borderwidth=10, font=('times',15, 'bold'))
                            type11.grid(row=5,column=2,padx=50,pady=20)
                            
                            type12=Label(Frame_login7,text="ENTER YOUR CVV",font=('times',15, 'bold'),bg="white",fg="black")
                            type12.grid(row=6,column=2)

                            type13=Entry(Frame_login7,width=35,borderwidth=10, font=('times',15, 'bold'))
                            type13.grid(row=7,column=2)
                            
                            Submit11 = Button(Frame_login7,text="PROCEED ==>",command=Next,width=15,height=2,font=('times',15,'italic'),bg="dodgerblue",fg="white")
                            Submit11.grid(row=8,column=2,pady=20,padx=50,columnspan=4)
                            
                         
                            
                        Room =['Normal','Suite','Deluxe']
                
                        cli2=StringVar()
                        cli2.set(Room[0])
                        
                        drop3=OptionMenu(Frame_login6,cli2,*Room,command=selected)
                        drop3.grid(row=2,column=1,padx=30,pady=50)
                        drop3.config(width= 30, height= 2,font=('times', 15))
                        
                        Room_label3 = Label(Frame_login6,text="AVAILABLE ROOM....",font=('Cooper Black',15, 'bold'),bg="white",fg="black")
                        Room_label3.grid(row=3,column=0,padx=50,pady=20)
                        
                        Room_label2 = Label(Frame_login6,text="SELECT ROOM",font=('times',15, 'bold'),bg="white",fg="black")
                        Room_label2.grid(row=4,column=0,padx=50,pady=30)
                        
                        Room_label4 = Label(Frame_login6,text="ARRIVAL DATE",font=('times',15, 'bold'),bg="white",fg="black")
                        Room_label4.grid(row=1,column=2)
                        
                        Room_label5 = Label(Frame_login6,text="DEPARTURE DATE",font=('times',15, 'bold'),bg="white",fg="black")
                        Room_label5.grid(row=3,column=2)
                        
                        arrival = Calendar(Frame_login6, selectmode="day", year=Year,month=Month,day=Day,mindate=todays_date)
                        arrival.place(x=900,y=120)
                
                        departure = Calendar(Frame_login6, selectmode="day",year=Year,month=Month,day=Day,mindate=todays_date)
                        departure.place(x=900,y=375)
                        
                        Room_label6 = Label(Frame_login6,text="CAR PARKING ACCESS?",font=('times',15, 'bold'),bg="white",fg="black")
                        Room_label6.grid(row=5,column=0,padx=30,pady=30)
                        
                        CAR_PARKING=["YES","NO"]
                        car_parks=StringVar()
                        car_parks.set("CHOOSE!!")
                        car=OptionMenu(Frame_login6,car_parks,*CAR_PARKING)
                        car.grid(row=5,column=1,padx=20,pady=20)
                        car.config(width= 30, height= 2,font=('times', 15))
                        
                        Submit7 = Button(Frame_login6,text="PROCEED ==>",command=Proceed,width=15,height=2,font=('Cooper Black',15,'italic'),bg="dodgerblue",fg="white")
                        Submit7.grid(row=6,column=0,pady=20,padx=50,columnspan=4)
                        
                        
                        
                    
                    if(len(F_N)!=0 and len(L_N)!=0 and len(A_N)!=0 and len(City)!=0 and len(Zip_Code)!=0 and len(Phone)!=0 and len(Mail)!=0):
                        if re.fullmatch(r'[a-zA-Z][a-zA-Z ]*',F_N):
                            if re.fullmatch(r'[a-zA-Z][a-zA-Z ]*',L_N):
                                if re.fullmatch(r'[a-zA-Z][a-zA-Z ]*',A_N):
                                    if re.fullmatch(r'[a-zA-Z][a-zA-Z ]*',City):
                                        if re.fullmatch(r'\d{4}|\d{6}',Zip_Code):
                                            if re.fullmatch(r'^((\+91)|)[789]{1}\d{9}$',Phone):
                                                if re.fullmatch(r'\b[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}\b',Mail):
                                                    
                                                    #Automically generating Guest ID
                                                    
                                                        sql_check="""SELECT * FROM User_Details_Table1"""
                                                        cursor.execute(sql_check)
                                                        row=cursor.fetchall()
                                                        row_length=(len(row))+100
                                                        Guest_id="G"+str("22")+"PMB"+str(row_length)
                                                        
                                                        #data insertion
                                                        cursor.execute("INSERT INTO User_Details_Table1 (G_ID,First_Name,Last_Name,Area_Name,City,State,Zip_Code,Country,Phone_Number,Mail_ID) VALUES (:G_ID,:First_Name,:Last_Name,:Area_Name,:City,:State,:Zip_Code,:Country,:Phone_Number,:Mail_ID)",
                                                                    {
                                                                            'G_ID':Guest_id,
                                                                            'First_Name':F_N,
                                                                            'Last_Name':L_N,
                                                                            'Area_Name':A_N,
                                                                            'City':City,
                                                                            'State':state,
                                                                            'Zip_Code':Zip_Code,
                                                                            'Country':Country,
                                                                            'Phone_Number':Phone,
                                                                            'Mail_ID':Mail
                                                                            }
                                                                    )
                                                        conn.commit()
                                                        
                                                        Check = Button(Frame_login5,text="Check >>",command=Checking,width=15,height=2,font=('Cooper Black',15,'italic'),bg="dodgerblue",fg="white")
                                                        Check.grid(row=10,column=1,pady=20,padx=20)
                                                        
                                                        
                                                else:
                                                    messagebox.showerror("showerror","Enter a Valid Mail Id",parent=top5)   
                                            else:
                                                messagebox.showerror("showerror","Enter a Valid Phone Number",parent=top5)
                                        else:
                                            messagebox.showerror("showerror","Enter a Valid Zip Code",parent=top5)
                                    else:
                                        messagebox.showerror("showerror","Enter a Valid City Name",parent=top5)
                                else:
                                    messagebox.showerror("showerror","Enter a Valid Area Name",parent=top5)            
                            else:
                                messagebox.showerror("showerror","Enter a Valid Last Name",parent=top5)
                        else:
                            messagebox.showerror("showerror","Enter a Valid First Name",parent=top5)
                        
                    else:
                        My_Label=Label(Frame_login5,text="Fill All the Data's",font=('Californian FB',15, 'bold'),bg="white",fg="black")
                        My_Label.grid(row=10,column=1)
                        My_Label.after(2000,My_Label.destroy)
                    
                    
                    
                
                title = Label(Frame_login5,text="PROVIDE YOUR DETAILS",font=('Cooper Black',15, 'italic'),bg="white",fg="#d77337")
                title.grid(row=0,column=0,columnspan=4)
                
                Book_label1 = Label(Frame_login5,text="FIRST NAME",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label1.grid(row=1,column=0,padx=30)
                
                Book_label2 = Label(Frame_login5,text="LAST NAME",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label2.grid(row=2,column=0,padx=30)
                
                Book_label4 = Label(Frame_login5,text="AREA NAME",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label4.grid(row=3,column=0,padx=30)
                
                Book_label5 = Label(Frame_login5,text="CITY",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label5.grid(row=4,column=0,padx=30)
                
                Book_label6 = Label(Frame_login5,text="STATE",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label6.grid(row=5,column=0,padx=30)
                
                Book_label7 = Label(Frame_login5,text="COUNTRY",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label7.grid(row=6,column=0,padx=30)
                
                Book_label8= Label(Frame_login5,text="ZIP CODE",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label8.grid(row=1,column=2,padx=30)
                
                Book_label9 = Label(Frame_login5,text="PHONE",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label9.grid(row=2,column=2,padx=30)
                
                Book_label10 = Label(Frame_login5,text="MAIL ID",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label10.grid(row=3,column=2)
                
                Book_label12 = Label(Frame_login5,text="SELECT DATE",font=('times',15, 'bold'),bg="white",fg="black")
                Book_label12.grid(row=4,column=2)
                
                #Book_label13 = Label(Frame_login5,text="DEPARTURE DATE",font=('times',15, 'bold'),bg="white",fg="black")
                #Book_label13.grid(row=7,column=2)
                
                todays_date = date.today()
                
                Year = todays_date.year
                Month = todays_date.month
                Day = todays_date.day
                #entry
                Book_Entry1=Entry(Frame_login5,width=35,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry1.grid(row=1,column=1,padx=50,pady=25)
                
                Book_Entry2=Entry(Frame_login5,width=35,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry2.grid(row=2,column=1,padx=50,pady=25)
                
                Book_Entry3=Entry(Frame_login5,width=35,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry3.grid(row=3,column=1,padx=50,pady=25)
                
                Book_Entry4=Entry(Frame_login5,width=35,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry4.grid(row=4,column=1,padx=50,pady=25)
                
                states=['Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh','Goa,Gujarat',
                        'Haryana','Himachal Pradesh','Jammu and Kashmir','Jharkhand','Karnataka','Kerala',
                        'Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha',
                        'Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh',
                        'Uttarakhand','West Bengal','Andaman and Nicobar','Chandigarh','Dadra and Nagar Haveli',
                        'Daman and Diu','Lakshadweep','Delhi','Puducherry','Others']
                
                cli=StringVar()
                cli.set(states[0])
                
                drop1=OptionMenu(Frame_login5,cli,*states)
                drop1.grid(row=5,column=1,pady=25)
                drop1.config(width = 40,height= 2,font=('times', 12))
                
                Country =['India','Other']
                
                cli1=StringVar()
                cli1.set(Country[0])
                
                drop2=OptionMenu(Frame_login5,cli1,*Country)
                drop2.grid(row=6,column=1,pady=25)
                drop2.config(width= 40,height= 2,font=('times', 12))
                
                Book_Entry10=Entry(Frame_login5,width=25,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry10.grid(row=1,column=3,pady=25)
                
                Book_Entry11=Entry(Frame_login5,width=25,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry11.grid(row=2,column=3,pady=25)
                
                Book_Entry12=Entry(Frame_login5,width=25,borderwidth=10, font=('times',15, 'bold'))
                Book_Entry12.grid(row=3,column=3,pady=25)
                
                cal = Calendar(Frame_login5, selectmode='day', year=Year,month=Month,day=Day,mindate=todays_date)
                cal.place(x=910,y=330)
                
                #cal1 = Calendar(Frame_login5, selectmode="day", year=2022,month=2,day=7)
                #cal1.place(x=930,y=500)
                
                Submit5 = Button(Frame_login5,text="SUBMIT",command=Personal_Details,width=15,height=2,font=('Cooper Black',15,'italic'),bg="black",fg="white")
                Submit5.grid(row=10,column=0,pady=20,padx=20)
                    
            
            Button(top2, image = photo,compound = TOP, height=350, width=650,command=Sites_Gallery).grid(row=0,column=0,padx=50)
            Label(top2,text="Green Palm Resort Best Views and Sites",font=('Cooper Black',20,'italic'),bg="white",fg="black").grid(row=1,column=0)
            Label(top2,text="Green Palm Resort Rooms",font=('Cooper Black',20,'italic'),bg="white",fg="black").grid(row=0,column=1)

            Button(top2, image = photo1,compound = TOP, height=350, width=650,command=Rooms_Gallery).grid(row=1,column=1,padx=50,pady=20)
            
            Next_btn=Button(top2,text="BOOK NOW >>",command=Booking,width=30,height=2,font=('Cooper Black',15,'italic'),bg="black",fg="white")
            Next_btn.place(x=150,y=700)
            
        Gallery=Button(top1,text="GALLERY >>",command=Gallery1,width=30,height=2,font=('Cooper Black',15, 'italic'),bg="aquamarine",fg="navy")
        Gallery.place(x=750,y=650)
        
        
    User_Name_1=User.get()
    Pass_1=Password.get()
    
    if(len(User.get())!=0 and len(Password.get())!=0):
    
        Query="""select * from Register_Table where User_Name=:User_Name_1 and Password=:Pass_1"""
        cursor.execute(Query,[User_Name_1,Pass_1])
        row=cursor.fetchone()
        try:
                if((User_Name_1==str(row[0])) and (Pass_1==str(row[2]))):
                    
                    Register.after(0,Register.destroy)
                    My_Label=Label(Frame_login,text="WELCOME TO PALM RESORTS !! ",font=('Californian FB',13, 'bold'),bg="white",fg="black")
                    My_Label.grid(row=5,column=0)
                    My_Label.after(1000,My_Label.destroy)
                    Next_btn=Button(Frame_login,text="NEXT >>",command=Next,width=25,height=2,font=('times',15, 'bold'),bg="bisque",fg="#d77337")
                    Next_btn.grid(row=3,column=1,padx=50,pady=20)

        except TypeError:
                myLabel=Label(Frame_login,text="No Such Account !",font=('Californian FB',15, 'bold'),bg="white",fg="black")
                myLabel.grid(row=5,column=1)
                myLabel.after(3000,myLabel.destroy)
                User.delete(0,END)
                Password.delete(0,END)
    else:
        
        My_Label=Label(Frame_login,text="Fill All the Data's",font=('Californian FB',15, 'bold'),bg="white",fg="black")
        My_Label.grid(row=5,column=1)
        My_Label.after(2000,My_Label.destroy)
    
def Submit():
    
    global My_Label,bg_1,bg_img1
    top = Toplevel()
    top.title("RESORTS BOOKER: REGISTRATION PAGE")
    top.geometry(f'{screen_width}x{screen_height}+{0}+{0}')
    
    bg_1 = ImageTk.PhotoImage(file="Palm.jpg")
    bg_img1 = Label(top,image=bg_1).place(x=0,y=0,relwidth=1,relheight=1)
    
    Frame_login1 = Frame(top,bg="white")
    Frame_login1.place(x=500,y=100,height=550,width=800)

    
    def sign_up():
        
        User_Name=User_1.get()
        E_Mail=Mail_ID.get()
        Pass=Password_1.get()
        Confirm_Pass1=Confirm_Pass.get()
        
        regex = r'\b[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}\b'
        
        if(re.fullmatch(regex, E_Mail)):
            if re.fullmatch(r'[A-Za-z0-9@#$%^&+=]{8,}', Pass):
                if(len(User_1.get())!=0 and len(Mail_ID.get())!=0 and len(Password_1.get())!=0 and len(Confirm_Pass.get())!=0):
                    if(Pass==Confirm_Pass1):
                                cursor.execute("INSERT INTO Register_Table VALUES(:User_1,:Mail_ID,:Password_1,:Confirm_Pass)",
                                        {
                                            'User_1': User_1.get(),
                                            'Mail_ID': Mail_ID.get(),
                                            'Password_1': Password_1.get(),
                                            'Confirm_Pass': Confirm_Pass.get()
                                        })
                                conn.commit()

                                click=Button(Frame_login1,text="LOGIN >>",width=25,height=2,font=('times',15, 'bold'),bg="bisque",fg="#d77337",command=top.destroy)
                                click.grid(row=6,column=1,pady=20,padx=50)
                    else:
                                My_Label=Label(Frame_login1,text=" PASSWORD DOESN'T MATCH ",font=('Californian FB',15, 'bold'),bg="white",fg="black")
                                My_Label.grid(row=6,column=1,pady=20,padx=50)
                                My_Label.after(2000,My_Label.destroy)
                                Password_1.delete(0,END)
                                Confirm_Pass.delete(0,END)
                else:
                    My_Label=Label(Frame_login1,text=" FILL ALL THE DATA'S ",font=('Californian FB',15, 'bold'),bg="white",fg="black")
                    My_Label.grid(row=6,column=1,pady=20,padx=50)
                    My_Label.after(2000,My_Label.destroy)
            else:
                messagebox.showerror("showerror", "Password Should Include Atleast 8 characters (Uppercase,Lowercase,Numbers and Special characters)",parent=top)
                
        else:
            My_Label=Label(Frame_login1,text="Give a valid Mail_ID",font=('Californian FB',15, 'bold'),bg="white",fg="black")
            My_Label.grid(row=6,column=1,pady=20,padx=50)
            My_Label.after(2000,My_Label.destroy)
            
    #Setting position

    User_1=Entry(Frame_login1,width=40,borderwidth=10, font=('times',15, 'bold'))
    User_1.grid(row=1,column=1,padx=50,pady=20)
    
    Mail_ID=Entry(Frame_login1,width=40,borderwidth=10, font=('times',15, 'bold'))
    Mail_ID.grid(row=2,column=1,padx=50,pady=20)
    
    Password_1=Entry(Frame_login1,width=40,borderwidth=10,font=('times',15, 'bold'),show='*')
    Password_1.grid(row=3,column=1,padx=50,pady=20)
    
    Confirm_Pass=Entry(Frame_login1,width=40,borderwidth=10,font=('times',15, 'bold'),show='*')
    Confirm_Pass.grid(row=4,column=1,padx=50,pady=20)

    #creating label

    Welcome_1 = Label(Frame_login1,text="REGISTER HERE",font=('impact',20, 'bold'),bg="white",fg="#d77337")
    Welcome_1.grid(row=0,column=0,columnspan=2)

    User_1l=Label(Frame_login1,text="Enter User Name",font=('Californian FB',20, 'bold'),bg="white",fg="black")
    User_1l.grid(row=1,column=0)
    
    Mail_l=Label(Frame_login1,text="Enter Mail ID",font=('Californian FB',20, 'bold'),bg="white",fg="black")
    Mail_l.grid(row=2,column=0)

    Password_1l=Label(Frame_login1, text="Enter Password",font=('Californian FB',20, 'bold'),bg="white",fg="black")
    Password_1l.grid(row=3,column=0)
    
    Confirm_Pass_l=Label(Frame_login1, text="Confirm Password",font=('Californian FB',20, 'bold'),bg="white",fg="black")
    Confirm_Pass_l.grid(row=4,column=0)
    
    Sign_Up=Button(Frame_login1,text="REGISTER HERE",command=sign_up,width=18,height=2,font=('times',15, 'bold'),bg="white",fg="#d77337")
    Sign_Up.grid(row=6,column=0,pady=20,padx=20,columnspan=1)
    
    

#Setting position

User=Entry(Frame_login,width=35,borderwidth=10, font=('times',15, 'bold'))
User.grid(row=1,column=1,padx=50,pady=20)

Password=Entry(Frame_login,width=35,borderwidth=10,font=('times',15, 'bold'),show="*")
Password.grid(row=2,column=1,padx=50,pady=20)

#creating label

Welcome = Label(root,text="WELCOME TO RESORTS BOOKER",font=('times',25, 'bold'),bg="#050505",fg="ivory")
Welcome.place(x=0,y=0,relwidth=1)

login = Label(Frame_login,text="LOGIN HERE",font=('impact',20, 'bold'),bg="white",fg="#d77337")
login.grid(row=0,column=0,columnspan=2)

User_l=Label(Frame_login,text="Enter User Name",font=('Californian FB',20, 'bold'),bg="white",fg="black")
User_l.grid(row=1,column=0)

Password_l=Label(Frame_login, text="Enter Password",font=('Californian FB',20, 'bold'),bg="white",fg="black")
Password_l.grid(row=2,column=0)

#creating Button

Login=Button(Frame_login,text="LOG IN",command=Submit1,width=15,height=2,font=('times',15, 'bold'),bg="white",fg="#d77337")
Login.grid(row=3,column=0,pady=20,padx=30)

Register=Button(Frame_login,text="CREATE NEW ACCOUNT!",command=Submit,width=30,height=2,font=('times',15, 'bold'),bg="white",fg="#d77337")
Register.grid(row=3,column=1,pady=20,padx=50)



mainloop()
# Out:
# [(43,), (45,), (48,), (49,), (50,), (51,), (53,), (54,), (55,), (56,), (57,), (58,), (60,)]
# 11 days, 0:00:00
# (6000.0,)
# 2
# 13440.0
# data_copied_successfully
# 26880.0
# DETAILS INSERTED INTO BOOKING DETAILS!!!
